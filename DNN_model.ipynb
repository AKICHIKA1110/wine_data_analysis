# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# %%
# モデル構築関数
def build_classification_model(input_shape, num_classes):
    model = Sequential([
        Dense(256, activation='relu', input_shape=(input_shape,)),
        Dense(128, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    return model

def build_regression_model(input_shape):
    model = Sequential([
        Dense(256, activation='relu', input_shape=(input_shape,)),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(1)  
    ])
    return model

# %%
#赤ワインのクラス分け予測モデルの学習を行うプログラム
# データの読み込み
red_wine = pd.read_csv('./WineQuality-RedWine.csv')

# 欠損値の処理
red_wine.fillna(red_wine.mean(), inplace=True)

# 特徴量とターゲットの分離
X_red = red_wine.drop('quality', axis=1)
y_red = red_wine['quality']
y_red = y_red - min(y_red)

# データの標準化
scaler_red = StandardScaler()
X_red_scaled = scaler_red.fit_transform(X_red)

# クラス数の設定
num_classes_red = len(y_red.unique())

# モデルの構築
model_red = build_classification_model(X_red_scaled.shape[1], num_classes_red)

# モデルのコンパイル
model_red.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# モデルの訓練
history_red = model_red.fit(X_red_scaled, y_red, epochs=50, validation_split=0.2, verbose=0)

# モデルの評価
accuracy_red = model_red.evaluate(X_red_scaled, y_red)[1]

print(f"赤ワインモデルの分類精度: {accuracy_red:.4f}")

# モデルの保存
model_red.save('./model/red_wine_classify_model.h5')
# Out:
# c:\Users\akich\OneDrive\Desktop\workspace\wine_data_analysis-main\wine_analysis\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.7943 - loss: 0.5216
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 赤ワインモデルの分類精度: 0.7505

# %%
#白ワインのクラス分け予測モデルの学習を行うプログラム
# データの読み込み
white_wine = pd.read_csv('./WineQuality-WhiteWine.csv')

# 欠損値の処理
white_wine.fillna(white_wine.mean(), inplace=True)

# 特徴量とターゲットの分離
X_white = white_wine.drop('quality', axis=1)
y_white = white_wine['quality']

# ラベルの値を0から始まるように調整
y_white = y_white - min(y_white)

# データの標準化
scaler_white = StandardScaler()
X_white_scaled = scaler_white.fit_transform(X_white)

# クラス数の設定
num_classes_white = len(y_white.unique())

# モデルの構築
model_white = build_classification_model(X_white_scaled.shape[1], num_classes_white)

# モデルのコンパイル
model_white.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# モデルの訓練
history_white = model_white.fit(X_white_scaled, y_white, epochs=50, validation_split=0.2, verbose=1)

# モデルの評価
accuracy_white = model_white.evaluate(X_white_scaled, y_white)[1]

print(f"白ワインモデルの分類精度: {accuracy_white:.4f}")

# モデルの保存
model_white.save('./model/white_wine_calssify_model.h5')
# Out:
# Epoch 1/50
# c:\Users\akich\OneDrive\Desktop\workspace\wine_data_analysis-main\wine_analysis\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4115 - loss: 1.4747 - val_accuracy: 0.6000 - val_loss: 1.0778
# Epoch 2/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5321 - loss: 1.1560 - val_accuracy: 0.5796 - val_loss: 1.0439
# Epoch 3/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5521 - loss: 1.0970 - val_accuracy: 0.5612 - val_loss: 1.0456
# Epoch 4/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5597 - loss: 1.0650 - val_accuracy: 0.6153 - val_loss: 0.9664
# Epoch 5/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5587 - loss: 1.0591 - val_accuracy: 0.5735 - val_loss: 0.9992
# Epoch 6/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5657 - loss: 1.0466 - val_accuracy: 0.5724 - val_loss: 0.9936
# Epoch 7/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5662 - loss: 1.0300 - val_accuracy: 0.6010 - val_loss: 0.9625
# Epoch 8/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5800 - loss: 1.0032 - val_accuracy: 0.6000 - val_loss: 0.9571
# Epoch 9/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5679 - loss: 1.0077 - val_accuracy: 0.5969 - val_loss: 0.9511
# Epoch 10/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5762 - loss: 0.9963 - val_accuracy: 0.5878 - val_loss: 0.9536
# Epoch 11/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5899 - loss: 0.9890 - val_accuracy: 0.5847 - val_loss: 0.9674
# Epoch 12/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5869 - loss: 0.9833 - val_accuracy: 0.5673 - val_loss: 0.9976
# Epoch 13/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5732 - loss: 0.9772 - val_accuracy: 0.6010 - val_loss: 0.9597
# Epoch 14/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - accuracy: 0.5922 - loss: 0.9530 - val_accuracy: 0.5969 - val_loss: 0.9515
# Epoch 15/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.5854 - loss: 0.9406 - val_accuracy: 0.5745 - val_loss: 0.9970
# Epoch 16/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - accuracy: 0.5991 - loss: 0.9276 - val_accuracy: 0.5684 - val_loss: 0.9582
# Epoch 17/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - accuracy: 0.6082 - loss: 0.9187 - val_accuracy: 0.5765 - val_loss: 0.9613
# Epoch 18/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6101 - loss: 0.9118 - val_accuracy: 0.5561 - val_loss: 0.9758
# Epoch 19/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6217 - loss: 0.9088 - val_accuracy: 0.5520 - val_loss: 1.0032
# Epoch 20/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6137 - loss: 0.8968 - val_accuracy: 0.6061 - val_loss: 0.9483
# Epoch 21/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6320 - loss: 0.8783 - val_accuracy: 0.5694 - val_loss: 0.9322
# Epoch 22/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6335 - loss: 0.8873 - val_accuracy: 0.5694 - val_loss: 0.9466
# Epoch 23/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6400 - loss: 0.8541 - val_accuracy: 0.5704 - val_loss: 0.9733
# Epoch 24/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6398 - loss: 0.8520 - val_accuracy: 0.5480 - val_loss: 1.0089
# Epoch 25/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6403 - loss: 0.8623 - val_accuracy: 0.5388 - val_loss: 0.9787
# Epoch 26/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6555 - loss: 0.8493 - val_accuracy: 0.5633 - val_loss: 0.9695
# Epoch 27/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6467 - loss: 0.8338 - val_accuracy: 0.5622 - val_loss: 0.9775
# Epoch 28/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6693 - loss: 0.8344 - val_accuracy: 0.5357 - val_loss: 0.9915
# Epoch 29/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6733 - loss: 0.8163 - val_accuracy: 0.5490 - val_loss: 1.0330
# Epoch 30/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6650 - loss: 0.8260 - val_accuracy: 0.5602 - val_loss: 1.0117
# Epoch 31/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6775 - loss: 0.8004 - val_accuracy: 0.5633 - val_loss: 0.9921
# Epoch 32/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6784 - loss: 0.7908 - val_accuracy: 0.5520 - val_loss: 0.9892
# Epoch 33/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6843 - loss: 0.7911 - val_accuracy: 0.5541 - val_loss: 1.0424
# Epoch 34/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6843 - loss: 0.7705 - val_accuracy: 0.5673 - val_loss: 0.9950
# Epoch 35/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6927 - loss: 0.7838 - val_accuracy: 0.5235 - val_loss: 1.0792
# Epoch 36/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - accuracy: 0.6983 - loss: 0.7596 - val_accuracy: 0.5735 - val_loss: 1.0172
# Epoch 37/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - accuracy: 0.6868 - loss: 0.7637 - val_accuracy: 0.5755 - val_loss: 0.9933
# Epoch 38/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6945 - loss: 0.7528 - val_accuracy: 0.5408 - val_loss: 1.0649
# Epoch 39/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7026 - loss: 0.7409 - val_accuracy: 0.5398 - val_loss: 1.0605
# Epoch 40/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6936 - loss: 0.7273 - val_accuracy: 0.5480 - val_loss: 1.0509
# Epoch 41/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7017 - loss: 0.7342 - val_accuracy: 0.5480 - val_loss: 1.0937
# Epoch 42/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7140 - loss: 0.7203 - val_accuracy: 0.5276 - val_loss: 1.0945
# Epoch 43/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7143 - loss: 0.7129 - val_accuracy: 0.5367 - val_loss: 1.0464
# Epoch 44/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7146 - loss: 0.7080 - val_accuracy: 0.5388 - val_loss: 1.0901
# Epoch 45/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7192 - loss: 0.6894 - val_accuracy: 0.5592 - val_loss: 1.0637
# Epoch 46/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7200 - loss: 0.6963 - val_accuracy: 0.5276 - val_loss: 1.1049
# Epoch 47/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7236 - loss: 0.6924 - val_accuracy: 0.5378 - val_loss: 1.0642
# Epoch 48/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7408 - loss: 0.6750 - val_accuracy: 0.5480 - val_loss: 1.1080
# Epoch 49/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7234 - loss: 0.6757 - val_accuracy: 0.5163 - val_loss: 1.1774
# Epoch 50/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - accuracy: 0.7373 - loss: 0.6563 - val_accuracy: 0.5418 - val_loss: 1.1366
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step - accuracy: 0.7404 - loss: 0.6706
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 白ワインモデルの分類精度: 0.7154

# %%
#赤ワインの等級回帰予測モデルの学習を行うプログラム

# データの読み込み
red_wine = pd.read_csv('./WineQuality-RedWine.csv')

# 欠損値の処理
red_wine.fillna(red_wine.mean(), inplace=True)

# 特徴量とターゲットの分離
X_red = red_wine.drop('quality', axis=1)
y_red = red_wine['quality']

# データの標準化
scaler_red = StandardScaler()
X_red_scaled = scaler_red.fit_transform(X_red)

# 赤ワインのモデル
model_red = build_regression_model(X_red_scaled.shape[1])

# モデルのコンパイル
model_red.compile(optimizer='adam', loss='mse', metrics=['mae'])

# モデルの訓練
history_red = model_red.fit(X_red_scaled, y_red, epochs=50, validation_split=0.2, verbose=1)

# モデルの評価
_, mae_red = model_red.evaluate(X_red_scaled, y_red)

print(f"赤ワインモデルのMAE: {mae_red}")

#モデルの保存
model_red.save('./model/red_wine_regression_model.h5')

# %%
#白ワインの等級回帰予測モデルの学習を行うプログラム

# データの読み込み
white_wine = pd.read_csv('./WineQuality-WhiteWine.csv')

# 欠損値の処理
white_wine.fillna(white_wine.mean(), inplace=True)

# 特徴量とターゲットの分離
X_white = white_wine.drop('quality', axis=1)
y_white = white_wine['quality']

# データの標準化
scaler_white = StandardScaler()
X_white_scaled = scaler_white.fit_transform(X_white)

# 白ワインのモデル
model_white = build_regression_model(X_white_scaled.shape[1])

# モデルのコンパイル
model_white.compile(optimizer='adam', loss='mse', metrics=['mae'])

# モデルの訓練
history_white = model_white.fit(X_white_scaled, y_white, epochs=50, validation_split=0.2, verbose=1)

# モデルの評価
_, mae_white = model_white.evaluate(X_white_scaled, y_white)

print(f"白ワインモデルのMAE: {mae_white}")

#モデルの保存
model_white.save('./model/white_wine_regression_model.h5')
